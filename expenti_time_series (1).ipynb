# %%
import pandas as pd
import matplotlib.pyplot as plt
#asssuming 'data.csv' contains time series data with a 'date' column
df=pd.read_excel("//content/Copy of Personal_Monthly_Expenditure_2021.xlsx")
df
# Out:
#    Month  Housing  Bills & Utilities  Food & Dining  Personal  \
# 0    Jan      800                210            400       100
# 1    Feb      800                180            350       100
# 2    Mar      800                170            420       100
# 3    Apr      800                160            400       120
# 4    May      800                150            420       100
# 5    Jun      800                150            380       100
# 6    Jul      800                150            420       120
# 7    Aug      800                150            420       100
# 8    Sep      800                150            400       120
# 9    Oct      800                170            420       100
# 10   Nov      800                200            390       120
# 11   Dec      800                220            400       100
#
#     Auto & Transport  Health & Fitness
# 0                100                60
# 1                125                70
# 2                120                60
# 3                100                60
# 4                100                80
# 5                130                60
# 6                100                60
# 7                100                80
# 8                110                60
# 9                100                60
# 10               100                50
# 11               115                60

# %%
print(df.head())
print(df.describe())
df.plot()

plt.title('Time Series Data')
plt.show()
# Out:
#   Month  Housing  Bills & Utilities  Food & Dining  Personal  \
# 0   Jan      800                210            400       100
# 1   Feb      800                180            350       100
# 2   Mar      800                170            420       100
# 3   Apr      800                160            400       120
# 4   May      800                150            420       100
#
#    Auto & Transport  Health & Fitness
# 0               100                60
# 1               125                70
# 2               120                60
# 3               100                60
# 4               100                80
#        Housing  Bills & Utilities  Food & Dining    Personal  \
# count     12.0          12.000000      12.000000   12.000000
# mean     800.0         171.666667     401.666667  106.666667
# std        0.0          25.524795      21.248886    9.847319
# min      800.0         150.000000     350.000000  100.000000
# 25%      800.0         150.000000     397.500000  100.000000
# 50%      800.0         165.000000     400.000000  100.000000
# 75%      800.0         185.000000     420.000000  120.000000
# max      800.0         220.000000     420.000000  120.000000
#
#        Auto & Transport  Health & Fitness
# count         12.000000         12.000000
# mean         108.333333         63.333333
# std           11.348475          8.876254
# min          100.000000         50.000000
# 25%          100.000000         60.000000
# 50%          100.000000         60.000000
# 75%          116.250000         62.500000
# max          130.000000         80.000000

# %%
monthly_mean=df.resample('M').mean()
print(monthly_mean)
